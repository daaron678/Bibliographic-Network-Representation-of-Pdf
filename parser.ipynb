# %%
import pymupdf  
import argparse 
import sys
from pathlib import Path

# %%
import re

# %%
pdf_path = "C:/Users/dylan/Documents/Spatial/Networks/knowledge map/article.pdf"
pdf_path_obj = Path(pdf_path).resolve()
if not pdf_path_obj.exists():
    raise FileNotFoundError(f"PDF file not found: {pdf_path}")

if not pdf_path_obj.is_file():
    raise ValueError(f"Path is not a file: {pdf_path}")

# %%
def parse_text(pdf_path:str) ->list :
    try:
        doc = pymupdf.open(pdf_path) 
        page = doc[1]
        page_count = len(doc) - 1
        text = []   # list where each item is the text within each paragraph
        for page_num in range(page_count):
            page = doc[page_num]
            # a block contains text descriptions for each section in the page
            blocks = page.get_text("blocks", sort = False)
            # for every section in the page
            for block in blocks:
                # print("block #", block[5])
                # a block contains multiple paragraphs
                paragraphs = block[4]
                # a "." follwed by " " and then "\n" indicates a new paragraph within the text
                # get paragraphs, a list with each paragraph as an item
                paragraphs = re.split(r'(?<=\.) \r?\n', paragraphs)
                for paragraph in paragraphs:
                    paragraph = paragraph.replace("\n", "")
                    text.append(paragraph)
                # _ = [print(paragraph, '\n NEW PARAGRAPH \n') for paragraph in paragraphs] 
        print(f"[MAIN.PY DEBUG] Extracted {len(text)} paragraphs from {page_count} pages", file=sys.stderr, flush=True)
        return text
    except Exception as e:
        print(f"[MAIN.PY DEBUG] Error extracting PDF text: {e}", file=sys.stderr, flush=True)
        raise Exception(f"Failed to extract text from PDF: {e}")

# %%
text = parse_text(pdf_path)
# text[9] corresponds to first page Abstract
# Out:
# [MAIN.PY DEBUG] Extracted 150 paragraphs from 6 pages

# %%
import networkx as nx

# %%
semantic_path = "C:/Users/dylan/Documents/Spatial/Networks/knowledge map/Bibliographic-Network-Representation-of-Pdf/docs/semantic_net_1.2.gexf"
network = nx.read_gexf(semantic_path)

# %%
type(network.nodes)
network.nodes
nodes = list(network.nodes)

# %%
len(list(network.nodes))
print(len(nodes))
print(nodes)
type(text)
# Out:
# 204
# ['heat exposure', 'house', 'theme', 'census tract', 'smooth', 'human', 'disproportionately', 'table', 'hospital admission', 'health', 'local', 'supplementary data', 'study', 'multiple', 'empirical baye', 'vulnerable areas', 'metropolitan areas', 'stabilize', 'hospital emergency', 'higher social', 'statistical analysis', 'statistical relationship', 'heat related morbidity', 'socio economic status', 'socioeconomic status', 'spatially', 'visits mortality', 'additionally', 'identify', 'schwartz', 'social vulnerability', 'empirical bayesian', 'white', 'wilhelmi', 'heat morbidity', 'tool', 'linke', 'heat related mortality', 'individual', 'generally', 'data', 'heat illness', 'high', 'hazardous heat event', 'heat related death', 'total heat', 'geographically weight', 'cramp', 'caus', 'method', 'level', 'status', 'observe', 'unstable', 'bivariate', 'elderly population', 'metropolitan', 'distribution', 'determinant', 'heat', 'death', 'county level', 'department', 'public health', 'illness', 'scale', 'heat vulnerable areas', 'exhaustion', 'household composition', 'descriptive', 'mortality rate', 'event', 'risk factor', 'spatial analysis', 'explore', 'group', 'social', 'social characteristic', 'conduct', 'evaluate', 'rank', 'hallisey', 'temporal', 'education', 'predictor', 'exposure', 'disproportionately higher', 'emergency department', 'hospital', 'labor', 'heat mortality', 'heat event', 'spatially linke', 'symptom', 'ranke', 'spatially unstable', 'poisson regression', 'community health', 'weighted pearson', 'entry', 'smoothe', 'socioeconomic', 'examine', 'southern', 'flanagan', 'visit rate', 'household', 'vulnerability', 'morbidity', 'consider multiple', 'temperature', 'environmental', 'compare', 'heat related health outcome', 'positive spatial', 'individual predictor', 'mortality regression', 'chuang', 'social determinant', 'themes table', 'elderly', 'outdoor labor', 'environ', 'univariate global', 'empirical', 'climate change', 'emergency', 'dataset', 'poverty', 'mapping community', 'mortality', 'contributing factor', 'increased likelihood', 'indicator', 'analysis', 'county', 'cold spot', 'relationship', 'test', 'exploration', 'community', 'resource', 'smoothed mortality rate', 'spatial autocorrelation analysis', 'positive spatial autocorrelation', 'population', 'regression analysis', 'univariate', 'statistical', 'health perspect', 'disaster', 'health outcome', 'global', 'factor', 'percentile ranke', 'older', 'weight', 'bivariate global', 'extreme heat', 'spatial autocorrelation', 'rate', 'white status', 'race', 'heat safety', 'environ health perspect', 'risk', 'characteristic', 'strong', 'descriptive statistic', 'urban', 'regression', 'united states', 'climate', 'heat related illness', 'heat related mortality rate', 'increased education', 'vulnerable', 'geographically', 'heatrelate', 'geographically weighted pearson', 'natural hazard', 'heatrelated mortality', 'spatial', 'johnson', 'heat stress', 'hazard', 'analyses', 'loss', 'areas', 'reduce human vulnerability', 'extreme heat event', 'manag', 'extreme heat related mortality', 'statistic', 'environ health', 'census tract level', 'humid subtropical climate', 'evidence', 'region', 'spot', 'natural', 'correlation', 'mortality data', 'highest']
# list

# %%
import numpy as np

# %%
b_matrix = np.zeros((len(nodes), len(nodes)))

# %%
b_matrix.shape
# Out:
# (204, 204)

# %%
biblio_dict = {}   # keyword (str) : cocitations (dictionary)

# for s_node in nodes:
#     for t_node in (nodes - s_node): 
for paragraph in text:
    kwords_in_pgraph = set()
    for keyword in nodes:
        pattern = re.findall(keyword, paragraph)
        if pattern:
            kwords_in_pgraph.add(keyword)
    for row in range(b_matrix.shape[0]):
        if nodes[row] not in kwords_in_pgraph:
            continue
        for column in 




    for keyword in kwords_in_pgraph:
        biblio_dict.update({keyword: len()})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[157], line 2
#       1 biblio_dict = {}   # dictionary to store keys (keywords) and values ()
# ----> 2 biblio_dict.keys = [node for node in nodes]
#
# AttributeError: 'dict' object attribute 'keys' is read-only

# %%
# nx.write_network_text(graph = nx.Graph, path = semantic_path)
nx.write_network_text(network)
# Out:
# ╟── manag
# ╎   └── disaster
# ╎       ├── vulnerability
# ╎       │   ├── theme
# ╎       │   │   ├── house
# ╎       │   │   ├── individual
# ╎       │   │   │   ├── predictor
# ╎       │   │   │   │   ├── heat illness
# ╎       │   │   │   │   │   ├── heat ─ theme, vulnerability, predictor
# ╎       │   │   │   │   │   │   ├── heat exposure
# ╎       │   │   │   │   │   │   │   └── exposure ─ heat
# ╎       │   │   │   │   │   │   │       └── environmental ─ heat, vulnerability
# ╎       │   │   │   │   │   │   │           └── emergency
# ╎       │   │   │   │   │   │   │               ├── hospital emergency
# ╎       │   │   │   │   │   │   │               │   ├── hospital ─ heat, emergency
# ╎       │   │   │   │   │   │   │               │   │   ├── hospital admission ─ heat
# ╎       │   │   │   │   │   │   │               │   │   ├── data ─ vulnerability, heat
# ╎       │   │   │   │   │   │   │               │   │   │   ├── supplementary data
# ╎       │   │   │   │   │   │   │               │   │   │   ├── additionally
# ╎       │   │   │   │   │   │   │               │   │   │   │   ├── multiple ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   ├── factor ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   ├── mortality rate ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   ├── smooth
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── empirical ─ mortality rate
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── empirical baye
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── empirical bayesian ─ mortality rate
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   ├── mortality ─ smooth, data, heat, mortality rate, vulnerability, empirical, factor
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── disproportionately
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └── disproportionately higher
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── table ─ theme, heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── themes table ─ theme
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └── descriptive
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       ├── statistic
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   ├── race
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │   └── population ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       ├── white
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   ├── white status
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │   └── status ─ theme, white
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │       ├── socio economic status ─ theme
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │       ├── socioeconomic status
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │       │   └── socioeconomic ─ status
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │       ├── poverty ─ white, population
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       ├── group ─ heat, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       │   └── older ─ population
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       │   └── descriptive statistic ─ descriptive
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── health ─ vulnerability, heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── health outcome ─ heat, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   ├── study ─ health, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── social vulnerability ─ theme, health, health outcome, vulnerability, mortality, heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── social ─ theme, health, study, multiple, heat, factor, health outcome, vulnerability, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── higher social
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── generally ─ social vulnerability, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── region ─ social
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │       └── united states ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │           └── areas ─ health, heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               ├── vulnerable areas ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   ├── heat vulnerable areas ─ heat, areas
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   └── vulnerable ─ vulnerable areas, heat, areas
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │       └── metropolitan ─ vulnerable areas, areas
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │           └── metropolitan areas ─ areas
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               ├── high ─ social vulnerability, vulnerability, mortality, heat, mortality rate, social
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   ├── visit rate ─ theme, heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   ├── heat related mortality ─ mortality, heat, mortality rate
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   ├── local ─ heat, mortality, mortality rate
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   ├── bivariate ─ heat, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   ├── spatial ─ theme, health, study, social vulnerability, heat related mortality, data, heat, mortality rate, social, visit rate, vulnerability, mortality, health outcome
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── statistical analysis
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   ├── analysis ─ health, social vulnerability, data, bivariate, heat, social, vulnerability, mortality, spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── spatial analysis ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── dataset
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── regression ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── poisson regression
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └── regression analysis ─ analysis
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── spatial autocorrelation analysis ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └── spatial autocorrelation ─ analysis, spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       ├── positive spatial ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       │   └── positive spatial autocorrelation ─ spatial, spatial autocorrelation
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── bivariate global ─ bivariate, heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └── global ─ local, bivariate, heat, analysis
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       ├── conduct ─ local, bivariate
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       │   ├── univariate ─ bivariate, global
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       │   │   ├── univariate global ─ global
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       │   │   └── test ─ local, bivariate, conduct, spatial, global
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── statistical ─ statistical analysis, social vulnerability, heat, social, vulnerability, spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── statistical relationship ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   └── relationship ─ health, social vulnerability, heat, mortality rate, social, vulnerability, mortality, spatial, health outcome, statistical
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       ├── determinant ─ health, heat, social
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       │   └── social determinant ─ heat, social, relationship
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       ├── explore
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       ├── heat related health outcome ─ health, heat, social, spatial, health outcome
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       ├── strong
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │       └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── analyses ─ spatial
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── distribution
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── temporal
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── ranke ─ mortality, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   ├── census tract
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── level ─ data, heat, vulnerability, mortality, ranke
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── county level ─ data, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   └── county ─ data, level, heat, ranke, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   ├── census tract level ─ census tract, ranke
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   ├── percentile ranke
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── exploration ─ social vulnerability, social, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── mortality data ─ data, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   ├── spot ─ heat, vulnerability, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   └── cold spot ─ local, heat, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   ├── extreme heat ─ social vulnerability, heat, social, vulnerability, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   ├── illness ─ hospital emergency, heat illness, heat, predictor, hospital, emergency
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   └── heat related illness ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   ├── heat event ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   ├── hazardous heat event ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   ├── resource ─ heat, heat event
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   │   └── event ─ hazardous heat event, heat, heat event
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   ├── extreme heat event ─ heat, extreme heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   ├── extreme heat related mortality ─ heat related mortality, heat, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   ├── heat related mortality rate ─ heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   ├── rank ─ high, heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │   └── smoothe ─ heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   │       └── smoothed mortality rate ─ heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │               └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── hazard ─ social vulnerability, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── identify ─ vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── tool ─ vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── community ─ health, social vulnerability, heat, social, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │       ├── community health ─ health
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │       └── mapping community ─ vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── risk ─ heat, social, disaster, factor
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── risk factor ─ factor
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── natural hazard ─ hazard
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── natural ─ risk, hazard
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── social characteristic
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── characteristic ─ social
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── highest
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── evidence ─ social vulnerability, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── examine
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── heatrelate ─ mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └── heatrelated mortality ─ mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── public health
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └── department ─ health, emergency
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │       └── emergency department ─ emergency
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── environ health perspect
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   ├── environ ─ health, heat, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── health perspect ─ health, environ health perspect
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── environ health ─ health, environ, environ health perspect
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── indicator ─ vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── education ─ factor
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └── increased education
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── spatially ─ heat, mortality rate, vulnerability
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── spatially unstable ─ mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └── unstable ─ spatially, empirical bayesian, mortality, mortality rate, empirical
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── spatially linke
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └── linke ─ spatially
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── visits mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── heat mortality ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── correlation ─ heat, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   ├── weighted pearson
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── geographically weight
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── weight ─ weighted pearson, correlation
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── geographically ─ geographically weight, weighted pearson
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── geographically weighted pearson ─ geographically weight, weighted pearson, weight
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └── rate ─ theme, heat, mortality rate, mortality
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── morbidity ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   ├── heat related morbidity ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   │   └── heat morbidity ─ heat
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   ├── mortality regression
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   ├── stabilize
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   │   └── method
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   ├── consider multiple ─ multiple
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   ├── contributing factor ─ multiple
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   │   │   └── compare
# ╎       │   │   │   │   │   │   │               │   │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   │   └──  ...
# ╎       │   │   │   │   │   │   │               │   └──  ...
# ╎       │   │   │   │   │   │   │               └──  ...
# ╎       │   │   │   │   │   │   ├── human ─ vulnerability
# ╎       │   │   │   │   │   │   │   ├── loss
# ╎       │   │   │   │   │   │   │   └── reduce human vulnerability ─ heat, vulnerability
# ╎       │   │   │   │   │   │   ├── schwartz
# ╎       │   │   │   │   │   │   ├── wilhelmi
# ╎       │   │   │   │   │   │   ├── heat related death
# ╎       │   │   │   │   │   │   ├── total heat ─ theme
# ╎       │   │   │   │   │   │   ├── caus
# ╎       │   │   │   │   │   │   ├── observe
# ╎       │   │   │   │   │   │   ├── symptom
# ╎       │   │   │   │   │   │   ├── heat safety
# ╎       │   │   │   │   │   │   ├── heat stress
# ╎       │   │   │   │   │   │   ├── urban ─ vulnerability
# ╎       │   │   │   │   │   │   ├── climate
# ╎       │   │   │   │   │   │   │   ├── southern
# ╎       │   │   │   │   │   │   │   │   └── humid subtropical climate ─ climate
# ╎       │   │   │   │   │   │   │   ├── climate change
# ╎       │   │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   │   ├── increased likelihood
# ╎       │   │   │   │   │   │   ├── elderly
# ╎       │   │   │   │   │   │   │   └── elderly population
# ╎       │   │   │   │   │   │   ├── chuang
# ╎       │   │   │   │   │   │   ├── temperature
# ╎       │   │   │   │   │   │   ├── johnson
# ╎       │   │   │   │   │   │   └──  ...
# ╎       │   │   │   │   │   └──  ...
# ╎       │   │   │   │   ├── individual predictor ─ individual
# ╎       │   │   │   │   └──  ...
# ╎       │   │   │   └──  ...
# ╎       │   │   ├── household
# ╎       │   │   │   └── household composition ─ theme
# ╎       │   │   └──  ...
# ╎       │   ├── scale
# ╎       │   ├── evaluate
# ╎       │   └──  ...
# ╎       └──  ...
# ╟── cramp
# ╎   └── exhaustion
# ╟── entry
# ╎   └── death
# ╟── flanagan
# ╎   └── hallisey
# ╙── labor
#     └── outdoor labor

# %%
nx.write_network_text(network, sources = ['mortality'])
# Out:
# ╙── mortality
#     ├── smooth
#     │   ├── mortality rate ─ mortality
#     │   │   ├── local ─ mortality
#     │   │   │   ├── heat ─ mortality rate, mortality
#     │   │   │   │   ├── heat exposure
#     │   │   │   │   │   └── exposure ─ heat
#     │   │   │   │   │       └── environmental ─ heat
#     │   │   │   │   │           ├── vulnerability ─ heat, mortality
#     │   │   │   │   │           │   ├── theme ─ heat
#     │   │   │   │   │           │   │   ├── house
#     │   │   │   │   │           │   │   ├── individual
#     │   │   │   │   │           │   │   │   ├── predictor ─ heat
#     │   │   │   │   │           │   │   │   │   ├── heat illness ─ heat
#     │   │   │   │   │           │   │   │   │   │   └── illness ─ heat, predictor
#     │   │   │   │   │           │   │   │   │   │       ├── hospital emergency
#     │   │   │   │   │           │   │   │   │   │       │   ├── hospital ─ heat, illness
#     │   │   │   │   │           │   │   │   │   │       │   │   ├── hospital admission ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   ├── data ─ vulnerability, heat, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   ├── supplementary data
#     │   │   │   │   │           │   │   │   │   │       │   │   │   ├── additionally
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   ├── multiple ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   ├── factor ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   ├── risk factor
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │   └── risk ─ heat, factor
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       ├── social ─ theme, multiple, heat, factor, vulnerability, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   ├── health ─ mortality, vulnerability, heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── health outcome ─ heat, social, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   ├── study ─ health, vulnerability, social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   ├── social vulnerability ─ theme, health, social, health outcome, vulnerability, mortality, heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   ├── analysis ─ health, data, heat, social, vulnerability, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   ├── statistical analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   ├── statistical ─ social vulnerability, heat, social, vulnerability, analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   ├── statistical relationship
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   ├── spatial ─ theme, health, study, statistical analysis, social vulnerability, data, heat, mortality rate, social, vulnerability, mortality, analysis, statistical, health outcome
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── heat related mortality ─ local, mortality, heat, mortality rate
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── visit rate ─ theme, heat, mortality rate, mortality, spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   ├── high ─ social vulnerability, vulnerability, mortality, heat, mortality rate, social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── areas ─ health, heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── vulnerable areas ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── heat vulnerable areas ─ heat, areas
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── vulnerable ─ vulnerable areas, heat, areas
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │       └── metropolitan ─ vulnerable areas, areas
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   │           └── metropolitan areas ─ areas
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── united states ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── region ─ social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │       └── generally ─ social vulnerability, vulnerability, social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   └── rank ─ heat, mortality rate, mortality, visit rate
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │       └── smoothe ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │           └── smoothed mortality rate ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── extreme heat ─ social vulnerability, heat, illness, social, vulnerability, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   ├── heat event ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── hazardous heat event ─ heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── resource ─ heat, heat event
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── event ─ hazardous heat event, heat, heat event
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── extreme heat event ─ heat, extreme heat
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   ├── extreme heat related mortality ─ heat related mortality, heat, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── heat related mortality rate ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── bivariate ─ local, heat, mortality, analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── test ─ local, spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   ├── conduct ─ local, bivariate
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── global ─ local, bivariate, heat, analysis, test
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── univariate global
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── univariate ─ bivariate, conduct, test, global
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   ├── bivariate global ─ bivariate, heat, analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── distribution
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── spatial analysis ─ analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── temporal
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── ranke ─ mortality, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── census tract
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   ├── level ─ data, heat, vulnerability, mortality, ranke
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── county level ─ data, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   │   └── county ─ data, level, heat, ranke, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   ├── census tract level ─ census tract, ranke
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── percentile ranke
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── heat related health outcome ─ health, heat, social, health outcome
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └── relationship ─ health, statistical relationship, social vulnerability, heat, mortality rate, social, vulnerability, mortality, spatial, health outcome, statistical
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │       ├── determinant ─ health, heat, social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │       │   └── social determinant ─ heat, social, relationship
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │       ├── explore
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │       ├── strong
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │       └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── positive spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── positive spatial autocorrelation ─ spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │   └── spatial autocorrelation ─ positive spatial, analysis, spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   │       └── spatial autocorrelation analysis ─ analysis, spatial
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── exploration ─ social vulnerability, social, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── regression ─ analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   ├── poisson regression
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   │   └── regression analysis ─ analysis
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── mortality data ─ data, mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   ├── analyses ─ statistical
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   ├── dataset
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   ├── community ─ health, heat, social, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   ├── identify ─ vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   ├── hazard ─ social vulnerability, social, vulnerability, risk
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   ├── natural hazard ─ risk
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   │   └── natural ─ risk, hazard
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   │   └── tool ─ vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   ├── community health ─ health
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   │   └── mapping community ─ vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   ├── evidence ─ social, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   ├── examine
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── heatrelate ─ mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   └── heatrelated mortality ─ mortality
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── public health
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   └── department ─ health
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │       ├── emergency ─ hospital emergency, illness, hospital, environmental
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │       │   └── emergency department ─ department
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │       └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── environ health perspect
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   ├── environ ─ health, heat, vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   ├── health perspect ─ health, environ health perspect
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   │   └── environ health ─ health, environ, environ health perspect
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── indicator ─ vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   ├── education ─ factor
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   │   └── increased education
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   ├── higher social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   ├── social characteristic
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   │   └── characteristic ─ social
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   ├── highest
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       ├── disaster ─ vulnerability
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       │   └── manag
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   │       └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   ├── consider multiple ─ multiple
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   ├── contributing factor ─ multiple
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   │   │   └── compare
#     │   │   │   │   │           │   │   │   │   │       │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       │   └──  ...
#     │   │   │   │   │           │   │   │   │   │       ├── heat related illness ─ heat
#     │   │   │   │   │           │   │   │   │   │       └──  ...
#     │   │   │   │   │           │   │   │   │   ├── individual predictor ─ individual
#     │   │   │   │   │           │   │   │   │   └──  ...
#     │   │   │   │   │           │   │   │   └──  ...
#     │   │   │   │   │           │   │   ├── socio economic status
#     │   │   │   │   │           │   │   │   └── status ─ theme
#     │   │   │   │   │           │   │   │       ├── socioeconomic status
#     │   │   │   │   │           │   │   │       │   └── socioeconomic ─ status
#     │   │   │   │   │           │   │   │       ├── white
#     │   │   │   │   │           │   │   │       │   ├── white status ─ status
#     │   │   │   │   │           │   │   │       │   ├── poverty ─ status
#     │   │   │   │   │           │   │   │       │   │   └── population ─ white, heat
#     │   │   │   │   │           │   │   │       │   │       ├── group ─ heat, mortality
#     │   │   │   │   │           │   │   │       │   │       │   └── older ─ population
#     │   │   │   │   │           │   │   │       │   │       ├── race
#     │   │   │   │   │           │   │   │       │   │       │   └── statistic
#     │   │   │   │   │           │   │   │       │   │       │       ├── descriptive
#     │   │   │   │   │           │   │   │       │   │       │       │   ├── table ─ theme, heat, mortality
#     │   │   │   │   │           │   │   │       │   │       │       │   │   └── themes table ─ theme
#     │   │   │   │   │           │   │   │       │   │       │       │   └── descriptive statistic ─ statistic
#     │   │   │   │   │           │   │   │       │   │       │       └──  ...
#     │   │   │   │   │           │   │   │       │   │       └──  ...
#     │   │   │   │   │           │   │   │       │   └──  ...
#     │   │   │   │   │           │   │   │       └──  ...
#     │   │   │   │   │           │   │   ├── rate ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   │   └── heat mortality ─ heat, mortality
#     │   │   │   │   │           │   │   │       └── correlation ─ heat, mortality
#     │   │   │   │   │           │   │   │           ├── weighted pearson
#     │   │   │   │   │           │   │   │           │   ├── geographically weight
#     │   │   │   │   │           │   │   │           │   │   ├── weight ─ weighted pearson, correlation
#     │   │   │   │   │           │   │   │           │   │   │   ├── geographically ─ geographically weight, weighted pearson
#     │   │   │   │   │           │   │   │           │   │   │   │   └── geographically weighted pearson ─ geographically weight, weighted pearson, weight
#     │   │   │   │   │           │   │   │           │   │   │   └──  ...
#     │   │   │   │   │           │   │   │           │   │   └──  ...
#     │   │   │   │   │           │   │   │           │   └──  ...
#     │   │   │   │   │           │   │   │           └──  ...
#     │   │   │   │   │           │   │   ├── household
#     │   │   │   │   │           │   │   │   └── household composition ─ theme
#     │   │   │   │   │           │   │   ├── total heat ─ heat
#     │   │   │   │   │           │   │   └──  ...
#     │   │   │   │   │           │   ├── human ─ heat
#     │   │   │   │   │           │   │   ├── loss
#     │   │   │   │   │           │   │   └── reduce human vulnerability ─ heat, vulnerability
#     │   │   │   │   │           │   ├── spatially ─ heat, mortality rate, mortality
#     │   │   │   │   │           │   │   ├── spatially unstable ─ mortality rate, mortality
#     │   │   │   │   │           │   │   │   └── unstable ─ spatially, mortality, mortality rate
#     │   │   │   │   │           │   │   │       ├── empirical bayesian ─ mortality rate, mortality
#     │   │   │   │   │           │   │   │       │   └── empirical ─ smooth, unstable, mortality rate, mortality
#     │   │   │   │   │           │   │   │       │       └── empirical baye
#     │   │   │   │   │           │   │   │       └──  ...
#     │   │   │   │   │           │   │   ├── spatially linke
#     │   │   │   │   │           │   │   │   └── linke ─ spatially
#     │   │   │   │   │           │   │   └──  ...
#     │   │   │   │   │           │   ├── scale
#     │   │   │   │   │           │   ├── evaluate
#     │   │   │   │   │           │   ├── urban ─ heat
#     │   │   │   │   │           │   ├── spot ─ local, heat, mortality
#     │   │   │   │   │           │   │   └── cold spot ─ local, heat, mortality
#     │   │   │   │   │           │   └──  ...
#     │   │   │   │   │           └──  ...
#     │   │   │   │   ├── heat related morbidity
#     │   │   │   │   │   └── morbidity ─ heat, mortality
#     │   │   │   │   │       └── heat morbidity ─ heat
#     │   │   │   │   ├── schwartz
#     │   │   │   │   ├── wilhelmi
#     │   │   │   │   ├── heat related death
#     │   │   │   │   ├── caus
#     │   │   │   │   ├── observe
#     │   │   │   │   ├── symptom
#     │   │   │   │   ├── heat safety
#     │   │   │   │   ├── heat stress
#     │   │   │   │   ├── climate
#     │   │   │   │   │   ├── southern
#     │   │   │   │   │   │   └── humid subtropical climate ─ climate
#     │   │   │   │   │   ├── climate change
#     │   │   │   │   │   └──  ...
#     │   │   │   │   ├── increased likelihood
#     │   │   │   │   ├── elderly
#     │   │   │   │   │   └── elderly population
#     │   │   │   │   ├── chuang
#     │   │   │   │   ├── temperature
#     │   │   │   │   ├── johnson
#     │   │   │   │   └──  ...
#     │   │   │   └──  ...
#     │   │   └──  ...
#     │   ├── stabilize
#     │   │   └── method
#     │   └──  ...
#     ├── disproportionately
#     │   └── disproportionately higher
#     ├── visits mortality
#     ├── mortality regression
#     └──  ...

# %%
for node in nodes:
    
    if node
